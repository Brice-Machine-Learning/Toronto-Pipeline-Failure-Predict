# %%
from toronto_pipeline_failure_predict.api.toronto_client import TorontoOpenDataClient

client = TorontoOpenDataClient()

results = client.search_datasets("watermain")
dataset = client.get_dataset(results["result"]["results"][0]["id"])

urls = client.get_resource_urls(dataset)
print(urls)
# Out:
# ['https://ckan0.cf.opendata.inter.prod-toronto.ca/datastore/dump/b82cb7f4-1fe0-401f-861c-bb05126cdc86', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/datastore/dump/7b685ae1-648c-4083-ab87-cb18ab66048b', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/4e0989b8-57b9-4629-a5bd-cc672f537593/resource/d9d97d68-72e8-4774-ace2-026da37e8da8/download/transmission-watermain-4326.csv', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/4e0989b8-57b9-4629-a5bd-cc672f537593/resource/fefc080e-db94-4b0e-8231-818805fc6157/download/transmission-watermain-4326.geojson', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/4e0989b8-57b9-4629-a5bd-cc672f537593/resource/2d03558b-ac2a-41a4-9b7d-ff132a61ef8e/download/transmission-watermain-2952.csv', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/4e0989b8-57b9-4629-a5bd-cc672f537593/resource/35b22f1c-6684-43ac-9101-0087f601d80b/download/distribution-watermain-4326.csv', 'https://ckan0.cf.opendata.inter.prod-toronto.ca/datase
# ...
